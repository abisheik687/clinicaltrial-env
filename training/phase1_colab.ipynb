# %% [markdown]
# # ClinicalTrialEnv Phase 1 GRPO
#
# This notebook installs the training dependencies, runs a fallback baseline, launches Phase 1 GRPO on the amendment task, and generates the judging plots.

# %%
# !pip install -r requirements.txt -r requirements-training.txt

# %%
# !python training/evaluate_models.py --policy fallback --output artifacts/eval/baseline_eval.json

# %%
# !python training/grpo_phase1.py --env-url http://localhost:7860 --output-dir artifacts/phase1_grpo

# %%
# !python training/evaluate_models.py --policy model --model-name artifacts/phase1_grpo/model --output artifacts/eval/trained_eval.json
# !python training/plot_results.py
